# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_accepted = pd.read_csv(r"Lending Club Default Data\accepted_2007_to_2018q4.csv\accepted_2007_to_2018Q4.csv", nrows = 100000)

print(df_accepted.head(10))
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
# 5  68426831        NaN    11950.0      11950.0          11950.0   36 months
# 6  68476668        NaN    20000.0      20000.0          20000.0   36 months
# 7  67275481        NaN    20000.0      20000.0          20000.0   36 months
# 8  68466926        NaN    10000.0      10000.0          10000.0   36 months
# 9  68616873        NaN     8000.0       8000.0           8000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# ...

# %%
df_rejected = pd.read_csv(r"Lending Club Default Data\rejected_2007_to_2018q4.csv\rejected_2007_to_2018Q4.csv", nrows = 100000)

print(df_rejected.head(10))
